# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
courses = pd.read_csv('Online_Courses.csv')

# %%
courses.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0                    Machine Learning Specialization
# 1           1        Introduction to Data Science Specialization
# 2           2  Data Science Fundamentals with Python and SQL ...
# 3           3       Key Technologies for Business Specialization
# 4           4                       Deep Learning Specialization
#
#                                                  URL  \
# 0  https://www.coursera.org/specializations/machi...
# 1  https://www.coursera.org/specializations/intro...
# 2  https://www.coursera.org/specializations/data-...
# 3  https://www.coursera.org/specializations/key-t...
# 4  https://www.coursera.org/specializations/deep-...
#
#                                          Short Intro      Category  \
# 0  #BreakIntoAI with Machine Learning Specializat...  Data Science
# 1  Launch your career in data science. Gain found...  Data Science
# ...

# %%
courses = courses.drop(columns=['Unnamed: 0'])

# %%
courses['combined_features'] = courses['Title'] + ' ' + courses['Short Intro'] + ' ' + courses['Skills']

# %%
courses['combined_features'] = courses['combined_features'].fillna('').str.lower()

# %%
courses.head()
# Out:
#                                                Title  \
# 0                    Machine Learning Specialization
# 1        Introduction to Data Science Specialization
# 2  Data Science Fundamentals with Python and SQL ...
# 3       Key Technologies for Business Specialization
# 4                       Deep Learning Specialization
#
#                                                  URL  \
# 0  https://www.coursera.org/specializations/machi...
# 1  https://www.coursera.org/specializations/intro...
# 2  https://www.coursera.org/specializations/data-...
# 3  https://www.coursera.org/specializations/key-t...
# 4  https://www.coursera.org/specializations/deep-...
#
#                                          Short Intro      Category  \
# 0  #BreakIntoAI with Machine Learning Specializat...  Data Science
# 1  Launch your career in data science. Gain found...  Data Science
# 2  Build the Foundation for your Data Science car...  Data Science
# ...

# %%
def preprocessed_text (text):
    text = text.lower()
    return text

# %%
user_text = "Hello how are you here to go"
user_text = preprocessed_text(user_text)
print(user_text)
# Out:
# hello how are you here to go

# %%
vectorizer = TfidfVectorizer(stop_words='english')
course_tfidf = vectorizer.fit_transform(courses['combined_features'])
user_tfidf = vectorizer.transform([user_text])

# %%
similarity = cosine_similarity(user_tfidf, course_tfidf)

# %%
top_index = similarity.argsort()[0][-5:][::-1]
recommended_courses = courses.iloc[top_index]

# %%
print(recommended_courses[['Title', 'URL', 'Short Intro']])
# Out:
#                                                   Title  \
# 8091                       Introduction to Industry 4.0
# 2701  Content Strategy for Professionals: Capstone P...
# 2688                             Managing Linux Systems
# 2689                        Geospatial Analysis Project
# 2690                               Parallel programming
#
#                                                     URL  \
# 8091  https://www.simplilearn.com/introduction-indus...
# 2701  https://www.coursera.org/learn/content-strateg...
# 2688  https://www.coursera.org/learn/managing-linux-...
# 2689  https://www.coursera.org/learn/gis-capstone?sp...
# 2690  https://www.coursera.org/learn/scala-parallel-...
#
#                                             Short Intro
# 8091                      Introduction to Industry 4.0
# 2701  The Capstone Project will let you demonstrate ...
# 2688  In this course, we look at how to manage a sys...
# 2689  In this project-based course, you will design ...
# ...

# %%
import pickle

with open('vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

with open('course_tfidf.pkl', 'wb') as f:
    pickle.dump(course_tfidf, f)
    
courses.to_csv('proprocessed_courses.csv', index = False)

# %%
with open('vectorizer.pkl', 'rb') as f:
    main_vectorizer = pickle.load(f)
    
with open('course_tfidf.pkl', 'rb') as f:
    course_vector = pickle.load(f)

# %%
preprocessed_courses = pd.read_csv('proprocessed_courses.csv')

# %%
def recommend_courses(user_text):
    user_text = user_text.lower()
    user_vector = main_vectorizer.transform([user_text])
    cos_sim = cosine_similarity(user_vector, course_vector)
    top_indices = cos_sim.argsort()[0][-5:][::-1]
    return preprocessed_courses.iloc[top_indices][['Title', 'URL', 'Short Intro']]

# %%
user_text = "Hello how are you here to go"
# print(recommend_courses(user_text)['Title'])
# Out:
# 8091                         Introduction to Industry 4.0
# 2701    Content Strategy for Professionals: Capstone P...
# 2688                               Managing Linux Systems
# 2689                          Geospatial Analysis Project
# 2690                                 Parallel programming
# Name: Title, dtype: object
